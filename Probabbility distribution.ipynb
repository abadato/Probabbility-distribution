# %%
## Probabbility distribution ##
### Next, we will learn Uniform and Nomra distribution #

# %%
# for inline plots in jupyter
# %matplotlib inline
# import matplotlib
import matplotlib.pyplot as plt
# for latex equations 
from IPython.display import Math, Latex
# for displaying images
from IPython.core.display import Image

# %%
# import seaborn
import seaborn as sns
# settinger for seaborn plotting style
sns.set(color_codes=True)
# # settinger for seaborn plot sizes
sns.set(rc={'figure.figsize':(5,5)})

# %%
# import uniform distribution = here we can start with Uniform distribution
from scipy.stats import uniform

# %%
# random numbers from uniform distribution

n = 10000
start = 20 
width = 50
data_uniform = uniform.rvs(size=n, loc = start, scale=width)

# %%
ax = sns.displot(data_uniform,
                 bins=100,
                 kde=True,
                 color='green')
ax.set(xlabel='Uniform Distribution', ylabel='Frequency')
plt.show()

# %%
from scipy.stats import norm

data_normal = norm.rvs(size=1500,loc=0,scale=1)

ax = sns.displot(data_normal,
                 bins=120,
                 kde=True,
                 color='red')
ax.set(xlabel='Normal Distr', ylabel='Freq')
plt.show()

# %%
# Normal Distribution
# xxxxx

# Gamma distribution 
# xxxx

## Exponential distribution
